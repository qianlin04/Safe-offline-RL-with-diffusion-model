# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hopper_medium_replay_v2_cost_data = {
    'no': {
        'score': [0.9557793663890777, 0.9237093565344762, 0.8528800955608857, 0.933016990388818, 0.9540868394986183],
        'cost': [610.834301900605, 542.1331122520526, 500.9211308157068, 540.8682903229185, 588.7259273477239],
    },
    490: {
        'score': [0.8824564334280961, 0.8785122058912692, 0.8585509655462602],
        'cost': [490.8778208688, 451.7831800909578, 482.82399666915313, 457.5803059920482]
    },
    470: {
        'score': [0.8381570311854041, 0.839772737259495, 0.8266447483013958, 0.8499761224333056, 0.8729401994826533],
        'cost': [422.21673963467765, 422.2613402733591, 372.73506071257253, 400.1279441762126, 417.98404620964396],
    },
    350: {
        'score': [0.8190151330331007, 0.8390697015260457, 0.8099676753539911, 0.8005688671608878, 0.776879390055493],
        'cost': [349.4715255524965, 350.78439899310115, 329.17664068116096, 308.63355688300726, 324.1379671326553],
    },
    280: {
        'score': [0.7561390826804416, 0.7470758993286943, 0.7485579884946142, 0.7741237829456412],
        'cost': [261.71404559128837, 270.65148849780684, 261.93056658216176, 281.026276779964],
    },
    210: {
        'score': [0.7120598240520306, 0.683820994679734, 0.680955047774668, 0.6730892719144129, 0.7015326218032002],
        'cost': [208.85608589616064, 200.06668063868358, 197.34551866162366, 193.45684902979818, 208.4392122980571],
    },
    140: {
        'score': [0.6090946251166328, 0.5994049995028884, 0.6219585583763424, 0.5557563672519836, 0.6145628975387779],
        'cost': [132.3507885771877, 128.14582679721207, 136.52453889175052, 110.78474563565058, 139.50728031502774],
    },
    70: {
        'score': [0.45183567424301796, 0.47128474168009604, 0.4576220554596431, 0.48357140943924887, 0.4558481879006326],
        'cost': [61.52372885481801, 64.11924768282337, 65.02168681651956, 65.4654502504031, 60.95324722186477],
    },
}

no_contraint_cost = np.mean(hopper_medium_replay_v2_cost_data['no']['cost'])
no_contraint_score = np.mean(hopper_medium_replay_v2_cost_data['no']['score'])

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
X, Y, Z = [], [], []
for k, v in hopper_medium_replay_v2_cost_data.items():
    if not isinstance(k, int): continue
    X.append(k*1.0/no_contraint_cost)
    Y.append(np.mean(v['score']))
    Z.append(np.mean(v['cost'])/no_contraint_cost)
ax1.plot(X, Y, marker='o', color='b')
ax2.plot(X, Z, marker='1', color='r')
ax2.plot([0, 1], [0, 1], linestyle='--')
ax1.set_xlabel('cost threshold')
ax1.set_ylabel('score', color='b')
ax2.set_ylabel('true cost', color='r')
# Out:
# Text(0, 0.5, 'true cost')

# %%
walker2d_medium_replay_v2_cost_data = {
    'no': {
        'score': [0.8373617367865206, 0.46780745435571186, 0.5016504140640972, 0.8312313052386145, 0.7941760485860888],
        'cost': [746.4494750688095, 633.5183869772063, 713.6602185384476, 743.494588416132, 711.3096587900666],
    },
    600: {
        'score': [0.49464057766252645, 0.31405994038192936, 0.6708845710483182, 0.553448509268355, 0.5684677821288857],
        'cost': [595.7383437251602, 521.8067844788648, 693.4228658240663, 683.3058129259633, 658.8023189279556],
    },
    500: {
        'score': [0.7297401447605855, 0.37302250527928393, 0.5143512750400127, 0.4188689018208153, 0.475762127935254],
        'cost': [595.7383437251602, 521.8067844788648, 693.4228658240663, 683.3058129259633, 658.8023189279556],
    },
    400: {
        'score': [0.6270219619312947, 0.5300698499074296, 0.4514795360443746, 0.5851705511992457, 0.5925586781000306],
        'cost': [418.1813087635561, 418.7771464756619, 434.42188809998567, 420.6671746173182, 420.2506768904411],
    },
    200: {
        'score': [0.0007457562670667898, 0.0055925611506533095, 0.07019588650780134, 0.008123543839373708, 0.0034909526059988543],
        'cost': [0.49464057766252645, 0.31405994038192936, 0.6708845710483182, 0.553448509268355, 0.5684677821288857],
    },
}

no_contraint_cost = np.mean(walker2d_medium_replay_v2_cost_data['no']['cost'])
no_contraint_score = np.mean(walker2d_medium_replay_v2_cost_data['no']['score'])

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
X, Y, Z = [], [], []
for k, v in walker2d_medium_replay_v2_cost_data.items():
    if not isinstance(k, int): continue
    X.append(k*1.0/no_contraint_cost)
    Y.append(np.mean(v['score']))
    Z.append(np.mean(v['cost'])/no_contraint_cost)
ax1.plot(X, Y, marker='o', color='b')
ax2.plot(X, Z, marker='1', color='r')
ax2.plot([0, 1], [0, 1], linestyle='--')
ax1.set_xlabel('cost threshold')
ax1.set_ylabel('score', color='g')
ax2.set_ylabel('true cost', color='b')
# Out:
# Text(0, 0.5, 'true cost')

# %%
walker2d_medium_replay_v2_cost_data = {
    'no': {
        'score': [0.8745641933488524, 0.6273214080324627, 0.8452326032552904, 0.5720495982564564, 0.5104889428246144],
        'cost': [160.6542092567628, 154.3148106930746, 150.90642905611313, 176.57216852273095, 187.72111166884594],
    },
    41: {
        'score': [0.010646000928523584, 0.005201062020960348, 0.19681232183509811, 0.19206789847770087, 0.20144697403452544],
        'cost': [53.66791239259512, 54.51251545613489, 52.05486553932107, 56.26227379296454, 58.41872591653718],
    },
    61.5: {
        'score': [0.6736408583359142, 0.18816787756377049, 0.05375197760531747, 0.7008390853248401, 0.6919121199879594],
        'cost': [58.239989027949, 61.875212275106854, 67.99985185099418, 59.17082655883875, 57.47934623811846],
    },
    82: {
        'score': [0.6711581334260991, 0.021703523047848974, 0.7501409398112915, 0.2628167382571769, 0.6856878154792339],
        'cost': [62.485803009552875, 61.402380957448415, 78.46304780451976, 81.19482130670171, 60.93863465219466],
    },
    102.5: {
        'score': [0.389703468634978, 0.554198454764191, 0.6587528225738419, 0.6434730376649422, 0.7881991836492728],
        'cost': [57.134054782814246, 102.6787290440254, 69.20699587287407, 69.20972125470469, 83.1565537058641],
    },
    123: {
        'score': [0.5961293019309372, 0.7455894782163162, 0.3316724557425903, 0.7807017523972056, 0.7530715111452906],
        'cost': [123.20565580747457, 91.18608697134633, 100.29846097852186, 102.42694666521379, 123.00496607965951],
    },
    143.5: {
        'score': [0.2837889606870788, 0.3219729074053228, 0.3522577219525202, 0.8333123094628662, 0.24399273062364135],
        'cost': [153.4203657946365, 144.5871516906368, 144.55279238197025, 123.31498363588982, 143.2099651188978],
    },
    164: {
        'score': [0.8608425916756256, 0.7216677564387431, 0.7625886565622961, 0.38338777789415207, 0.8202733705778836],
        'cost': [156.54245915615647, 163.31336055698984, 148.46687907873067, 163.83395940643297, 124.98984047676615],
    }
}

no_contraint_cost = np.mean(walker2d_medium_replay_v2_cost_data['no']['cost'])
no_contraint_score = np.mean(walker2d_medium_replay_v2_cost_data['no']['score'])

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
X, Y, Z = [], [], []
for k, v in walker2d_medium_replay_v2_cost_data.items():
    if isinstance(k, str): continue
    X.append(k*1.0/no_contraint_cost)
    Y.append(np.mean(v['score']))
    Z.append(np.mean(v['cost'])/no_contraint_cost)
ax1.plot(X, Y, marker='o', color='b')
ax2.plot(X, Z, marker='1', color='r')
ax2.plot([0, 1], [0, 1], linestyle='--')
ax1.set_xlabel('cost threshold')
ax1.set_ylabel('score', color='g')
ax2.set_ylabel('true cost', color='b')
# Out:
# Text(0, 0.5, 'true cost')
